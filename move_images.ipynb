# %%
import os

path = "/home/test/varsha/images/all_368_368"
dst_path = "/home/test/varsha/images/all_368_368_images"

classes = os.listdir(path)
# classes = [1]
subclasses = os.listdir(os.path.join(path, "1"))
for c in classes:
    dst = "{}/{}".format(dst_path, int(c))
    os.makedirs(dst, exist_ok=True)
    for sb in subclasses:
        cmd = "mv {}/{}/{}/* {}".format(path, int(c), sb, dst)
        os.system(cmd)
# rm -rf base/ in_bright_sunlight/ in_the_grass/ in_the_snow/ oil_painting/
# Out:
# mv: cannot stat '/home/test/varsha/images/all_368_368/161/oil_painting/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/161/in_the_snow/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/161/base/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/161/in_the_grass/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/161/in_bright_sunlight/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/937/oil_painting/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/937/in_the_snow/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/937/base/*': No such file or directory
# mv: cannot stat '/home/test/varsha/images/all_368_368/937/in_the_grass/*': No such file or directory
# ...
